# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshinchan/market/blob/main/Super_market_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import seaborn as sns
import plotly.express as px
from datetime import datetime as dt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/global_super_store_orders.tsv',sep = '\t')

# %% [markdown]
# #Column list###
#
#   ***Order ID***: Each order receives its own Order ID
#
#    ***Ship Date***:The definition of ship date is the date that the order is shipped from the seller or warehouse to the customer.
#
#    ***Ship Mode*** : The shipping mode is a way of shipping goods. More specifically, a shipping mode is the combination of a shipping carrier and the shipping service that is offered by that carrier.That column have a three types of mode **(Standard Class,Second Class,Same Day, First Class)**
#
#    ***Customer ID***: Customer ID means the unique means of identification allocated to or selected by the Customer in relation to any one or more of the Services whether in the form of a password, PIN or other form of personal identification, or any combination of any of them.
#
#    ***Customer Name***: Name of the Perion who purchase the product
#
#    ***Segment*** :In marketing, market segmentation is the process of dividing a broad consumer into sub-groups of consumers based on some type of shared characteristics
#
#    ***City***:The definition of a city is a town of significant size or an urban area with self-government
#
#    ***State***:State is defined as a territory with its own government and borders within a larger country
#
#    ***Country***:A country is defined as a nation, the people of the nation or land in a rural area
#
#    ***Postal Code***:A postal code is a series of letters or digits or both, sometimes including spaces or punctuation, included in a postal address for the purpose of sorting mail
#
#    ***Market***:A marker identifies a location on a map
#
#    ***Region*** : A region is a large area of land that is different from other areas of land
#
#    ***Product ID*** : Product identifiers are a series of numerical or alphanumerical digits that are used to identify a specific product
#
#    ***Category*** :The definition of a category is any sort of division or class
#
#    ***Sub-Category***: A category that is a subdivision of a larger category
#
#    ***Product Name***: A product name identifies a specific product
#
#    ***Sales*** :  Sales are activities related to selling or the number of goods sold in a given targeted time period
#
#    ***Quantity*** : an indefinite amount or number
#
#    ***Discount*** :A discount is the reduction of either the monetary amount or a percentage of the normal selling price of a product or service
#
#    ***Profit*** : Profit is the money a business pulls in after accounting for all expenses
#
#    ***Shipping Cost***: Just weigh the package and use a shipping cost calculator to get a shipping price
#
#    ***Order Priority***:Order of Priority means, in respect of any payment to be made by the Issuer before the Enforcement Date

# %%
df.head()
# Out:
#    Unnamed: 0  Row ID        Order ID Order Date Ship Date       Ship Mode  \
# 0       35180   29165   IN-2014-24531    8/15/14   8/19/14  Standard Class
# 1       39850   39615  CA-2014-130904    4/12/14   4/17/14  Standard Class
# 2       41575   39158  CA-2012-142993   10/12/12  10/17/12  Standard Class
# 3       12393    2193  MX-2013-169502    6/13/13   6/15/13    Second Class
# 4       45530   23217   IN-2014-50627    9/14/14   9/18/14  Standard Class
#
#   Customer ID      Customer Name    Segment           City  ...  \
# 0    AS-10285   Alejandro Savely  Corporate      Guangzhou  ...
# 1    HM-14980  Henry MacAllister   Consumer     Burlington  ...
# 2    KA-16525     Kelly Andreada   Consumer        Seattle  ...
# 3    AJ-10960       Astrea Jones   Consumer  Santo Domingo  ...
# 4    LW-16825     Laurel Workman  Corporate         Jinhua  ...
#
#         Product ID         Category  Sub-Category  \
# 0  OFF-SU-10001343  Office Supplies      Supplies
# 1  OFF-AR-10000127  Office Supplies           Art
# 2  TEC-AC-10003038       Technology   Accessories
# 3  TEC-AC-10001341       Technology   Accessories
# 4  OFF-EN-10001977  Office Supplies     Envelopes
#
#                                  Product Name   Sales Quantity Discount  \
# 0                  Elite Scissors, High Speed   45,06        2        0
# 1                                  Newell 321  20,992        8      0,2
# 2  Kingston Digital DataTraveler 16GB USB 2.0    17,9        2        0
# 3                    Enermax Memory Card, USB  183,36        3      0,2
# 4          Cameo Business Envelopes, Recycled    31,5        2        0
#
#    Profit Shipping Cost Order Priority
# 0     5,4          3,53         Medium
# 1  2,3616          2,28         Medium
# 2   3,401          1,91         Medium
# 3   22,92         25,54       Critical
# 4     6,9          1,14         Medium
#
# [5 rows x 25 columns]
# Warning: Total number of columns (25) exceeds max_columns (20) limiting to first (20) columns.

# %%
df.tail()
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 995   36853  CA-2012-125066 2012-12-14 2012-12-14  Standard Class    KD-16495
# 996   51024    NI-2011-1810 2011-11-21 2011-11-21    Second Class     RF-9840
# 997   30969   ID-2013-85732 2013-12-18 2013-12-18    Second Class    TG-21640
# 998   28335   IN-2014-40932 2014-09-25 2014-09-25  Standard Class    TG-21640
# 999   37924  CA-2011-138513 2011-05-23 2011-05-23  Standard Class    EH-13990
#
#        Customer Name    Segment        City        State  ...  \
# 995    Keith Dawkins  Corporate     Jackson  Mississippi  ...
# 996  Roy Französisch   Consumer        Kano         Kano  ...
# 997     Trudy Glocke   Consumer  Gold Coast   Queensland  ...
# 998     Trudy Glocke   Consumer    Bhiwandi  Maharashtra  ...
# 999    Erica Hackney   Consumer    Bellevue   Washington  ...
#
#             Category  Sub-Category                             Product Name  \
# 995        Furniture   Furnishings                          Stackable Trays
# 996  Office Supplies       Storage                  Smead Box, Single Width
# 997       Technology   Accessories        Enermax Numeric Keypad, Bluetooth
# 998  Office Supplies     Envelopes  Kraft Business Envelopes, Security-Tint
# 999  Office Supplies         Paper                               Xerox 1999
#
#      Sales Quantity Discount  Profit Shipping Cost Order Priority
# 995    616        2        0   19712           059           High   0
# 996    648        2       07    -954            12       Critical  07
# 997  68796        2       04  -41304           869         Medium  04
# 998   3288        2        0     426           234           High   0
# 999   1296        2        0   62208           185           High   0
#
# [5 rows x 25 columns]
# Warning: Total number of columns (25) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# # ***DATA PREPROSSING***

# %% [markdown]
# **Removed unwanted columns**

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# ***Data type conversion***

# %%
df['Sales'] = df['Sales'].str.replace(',','')
df.astype({'Sales':int})

# %%
df['Profit'] = df['Profit'].str.replace(',','')
df.astype({'Profit':int})

# %%
df.astype({'Row ID':str})

# %%
order_date=list(df['Order Date'])
df['Order Date']=pd.to_datetime(date)

# %%
ship_date=list(df['Ship Date'])
df['Ship Date']=pd.to_datetime(date)

# %%
df['Discount'] = df['Discount'].str.replace(',','')
df.astype({'Discount':int})

# %%
df['Shipping Cost'] = df['Shipping Cost'].str.replace(',','')
df.astype({'Shipping Cost':int})

# %%
new_df=df.astype({'Postal Code':str})

# %% [markdown]
# **Describe of Data Frame**

# %%
new_df.describe()
# Out:
#              Row ID     Quantity
# count   1000.000000  1000.000000
# mean   25571.221000     3.388000
# std    14570.032549     2.168908
# min       19.000000     1.000000
# 25%    13678.250000     2.000000
# 50%    25229.000000     3.000000
# 75%    38116.750000     4.000000
# max    51285.000000    14.000000

# %%
ship_mode = df.groupby('Ship Mode', as_index=False, sort=False)['Ship Mode'].agg({'Ship Mode':'count'})
ship_mode['Ship_Mode_Name']=new_df['Ship Mode'].unique()
px.pie(ship_mode,values='Ship Mode',names='Ship_Mode_Name')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="14b2e15c-be8c-4610-a3a5-cf052ab51f9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14b2e15c-be8c-4610-a3a5-cf052ab51f9b")) {                    Plotly.newPlot(                        "14b2e15c-be8c-4610-a3a5-cf052ab51f9b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Ship_Mode_Name=%{label}<br>Ship Mode=%{value}<extra></extra>","labels":["Standard Class","Second Class","Same Day","First Class"],"legendgroup":"","name":"","showlegend":true,"values":[585,197,56,162],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ti ...

# %% [markdown]
# **Information of Data frame**

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          1000 non-null   int64
#  1   Order ID        1000 non-null   object
#  2   Order Date      1000 non-null   datetime64[ns]
#  3   Ship Date       1000 non-null   datetime64[ns]
#  4   Ship Mode       1000 non-null   object
#  5   Customer ID     1000 non-null   object
#  6   Customer Name   1000 non-null   object
#  7   Segment         1000 non-null   object
#  8   City            1000 non-null   object
#  9   State           1000 non-null   object
#  10  Country         1000 non-null   object
#  11  Postal Code     1000 non-null   object
#  12  Market          1000 non-null   object
#  13  Region          1000 non-null   object
#  14  Product ID      1000 non-null   object
#  15  Category        1000 non-null   object
#  16  Sub-Category    1000 non-null   object
#  17  Product Name    1000 non-null   object
#  18  Sales           1000 non-null   object
#  19  Quantity        1000 non-null   int64
#  20  Discount        1000 non-null   object
#  21  Profit          1000 non-null   object
#  22  Shipping Cost   1000 non-null   object
#  23  Order Priority  1000 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(20)
# memory usage: 187.6+ KB

# %% [markdown]
# **Define the Roll of Data Frame**

# %%
new_df.shape[0]
# Out:
# 1000

# %% [markdown]
# **Define the Unique value of Data Frame**

# %%
unique=pd.DataFrame(new_df.nunique())
unique
# Out:
#                    0
# Row ID          1000
# Order ID         979
# Order Date       653
# Ship Date        653
# Ship Mode          4
# Customer ID      654
# Customer Name    552
# Segment            3
# City             633
# State            382
# Country           90
# Postal Code      129
# Market             7
# Region            13
# Product ID       957
# Category           3
# Sub-Category      17
# Product Name     827
# Sales            931
# Quantity          14
# Discount          21
# Profit           903
# Shipping Cost    848
# Order Priority     4
#                   21

# %%
px.bar(unique,text_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c394262a-05d3-4eac-8982-8da037fb70c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c394262a-05d3-4eac-8982-8da037fb70c7")) {                    Plotly.newPlot(                        "c394262a-05d3-4eac-8982-8da037fb70c7",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Row ID","Order ID","Order Date","Ship Date","Ship Mode","Customer ID","Customer Name","Segment","City","State","Country","Postal Code","Market","Region","Product ID","Category","Sub-Category","Product Name","Sales","Quantity","Discount","Profit","Shipping Cost","Order Priority",""],"xaxis":"x","y":[1000,979,653,653,4,654,552,3,633,382,90,129,7,13,957,3,17,827,931,14,21,903,848,4,21],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f ...
